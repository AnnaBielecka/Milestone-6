# %%
eq = input()
print(eq.replace(' ',''))

eq = eq.replace(' ','').replace('+','').replace('(','').replace(')','')
ap = eq.find('x^2')

a = int(eq[:ap])
print('a =',a)

eq = eq[ap+3:]
bp = eq.find('x')

b = int(eq[:bp])
print('b =',b)

eq = eq[bp+1:]
cp = eq.find('=')

c = int(eq[:cp])
print('c =',c)

x1 = (-b+(b**2-4*a*c)**(1/2))/(2*a)
x2 = (-b-(b**2-4*a*c)**(1/2))/(2*a)

print('x1 =',x1)
print('x2 =',x2)
# Out:
# 4x^2+(-2)x-2=0
# a = 4
# b = -2
# c = -2
# x1 = 1.0
# x2 = -0.5
